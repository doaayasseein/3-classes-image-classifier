# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier

#initiating required models
detector = cv2.SimpleBlobDetector_create()
descriptor = cv2.xfeatures2d.SIFT_create()

# %%
# data preparation 
train=[]
train_labels=[]
test=[]
test_labels=[]
######################################################################################################
# reading face train and test data 
for count in range(100):
    if ((count+1)==100):
        temp= ("C:/Users/doaa yasseein/Documents/jupyter notebooks/faces_train/img"+str((count+1))+".jpg")

    elif ((count+1)<10):
        temp= ("C:/Users/doaa yasseein/Documents/jupyter notebooks/faces_train/img00"+str((count+1))+".jpg")
    
    elif ((count+1)>10):
        temp= ("C:/Users/doaa yasseein/Documents/jupyter notebooks/faces_train/img0"+str((count+1))+".jpg")
    
    # features extraction & description  for images   
    image=cv2.imread(temp,1)
    keypoints= detector.detect(image)
    image_with_keypoints = cv2.drawKeypoints(im, keypoints, np.array([]), (0,0,255), cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS) 
    (kps,features) = descriptor.detectAndCompute(image_with_keypoints,None)
    cv2.drawKeypoints(image_with_keypoints,kp,image)   
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    hist = cv2.calcHist([hsv], [0, 1, 2], None, (8, 8, 8),[0, 180, 0, 256, 0, 256])
    hist = cv2.normalize(hist,hist)
    hist=hist.flatten()
    train.append(hist)
    train_labels.append(0)
    
for count in range(50):
    if ((count+1)<10):
        temp= ("C:/Users/doaa yasseein/Documents/jupyter notebooks/faces_test/img00"+str((count+1))+".jpg")
    
    elif ((count+1)>10):
        temp= ("C:/Users/doaa yasseein/Documents/jupyter notebooks/faces_test/img0"+str((count+1))+".jpg")
    
    # features extraction & description  for images       
    image=cv2.imread(temp,1)
    keypoints= detector.detect(image)
    image_with_keypoints = cv2.drawKeypoints(im, keypoints, np.array([]), (0,0,255), cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS) 
    (kps,features) = descriptor.detectAndCompute(image_with_keypoints,None)
    cv2.drawKeypoints(image_with_keypoints,kp,image)   
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    hist = cv2.calcHist([hsv1], [0, 1, 2], None, (8, 8, 8),[0, 180, 0, 256, 0, 256])
    hist = cv2.normalize(hist,hist)
    hist=hist.flatten()  
    test.append(hist)
    test_labels.append(0)
    

######################################################################################################

# reading car train and test data 
for count in range(100):
    if ((count+1)==100):
        temp= ("C:/Users/doaa yasseein/Documents/jupyter notebooks/cars_train/img"+str((count+1))+".jpg")

    elif ((count+1)<10):
        temp= ("C:/Users/doaa yasseein/Documents/jupyter notebooks/cars_train/img00"+str((count+1))+".jpg")
    
    elif ((count+1)>10):
        temp= ("C:/Users/doaa yasseein/Documents/jupyter notebooks/cars_train/img0"+str((count+1))+".jpg")
    
    # features extraction & description  for images          
    image=cv2.imread(temp,1)
    keypoints= detector.detect(image)
    image_with_keypoints = cv2.drawKeypoints(im, keypoints, np.array([]), (0,0,255), cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS) 
    (kps,features) = descriptor.detectAndCompute(image_with_keypoints,None)
    cv2.drawKeypoints(image_with_keypoints,kp,image)   
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    hist = cv2.calcHist([hsv], [0, 1, 2], None, (8, 8, 8),[0, 180, 0, 256, 0, 256])
    hist = cv2.normalize(hist,hist)
    hist=hist.flatten()
    train.append(hist)
    train_labels.append(1)

for count in range(50):
    if ((count+1)<10):
        temp= ("C:/Users/doaa yasseein/Documents/jupyter notebooks/cars_test/img00"+str((count+1))+".jpg")
    
    elif ((count+1)>10):
        temp= ("C:/Users/doaa yasseein/Documents/jupyter notebooks/cars_test/img0"+str((count+1))+".jpg")
    
    # features extraction & description for images        
    image=cv2.imread(temp,1)
    keypoints= detector.detect(image)
    image_with_keypoints = cv2.drawKeypoints(im, keypoints, np.array([]), (0,0,255), cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS) 
    (kps,features) = descriptor.detectAndCompute(image_with_keypoints,None)
    cv2.drawKeypoints(image_with_keypoints,kp,image)   
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    hist = cv2.calcHist([hsv], [0, 1, 2], None, (8, 8, 8),[0, 180, 0, 256, 0, 256])
    hist = cv2.normalize(hist,hist)
    hist=hist.flatten()
    test.append(hist)
    test_labels.append(1)
######################################################################################################
     
# reading motoebikes train and test data 
for count in range(100):
    if ((count+1)==100):
        temp= ("C:/Users/doaa yasseein/Documents/jupyter notebooks/motorbikes_train/img"+str((count+1))+".jpg")

    elif ((count+1)<10):
        temp= ("C:/Users/doaa yasseein/Documents/jupyter notebooks/motorbikes_train/img00"+str((count+1))+".jpg")
    
    elif ((count+1)>10):
        temp= ("C:/Users/doaa yasseein/Documents/jupyter notebooks/motorbikes_train/img0"+str((count+1))+".jpg")
    
    # features extraction & description  for images          
    image=cv2.imread(temp,1)
    keypoints= detector.detect(image)
    image_with_keypoints = cv2.drawKeypoints(im, keypoints, np.array([]), (0,0,255), cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS) 
    (kps,features) = descriptor.detectAndCompute(image_with_keypoints,None)
    cv2.drawKeypoints(image_with_keypoints,kp,image)   
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    hist = cv2.calcHist([hsv], [0, 1, 2], None, (8, 8, 8),[0, 180, 0, 256, 0, 256])
    hist = cv2.normalize(hist,hist)
    hist=hist.flatten()
    train.append(hist)
    train_labels.append(2)

for count in range(50):
    if ((count+1)<10):
        temp= ("C:/Users/doaa yasseein/Documents/jupyter notebooks/motorbikes_test/img00"+str((count+1))+".jpg")
    
    elif ((count+1)>10):
        temp=("C:/Users/doaa yasseein/Documents/jupyter notebooks/motorbikes_test/img0"+str((count+1))+".jpg")
    
    # features extraction & description for images           
    image=cv2.imread(temp,1)
    keypoints= detector.detect(image)
    image_with_keypoints = cv2.drawKeypoints(im, keypoints, np.array([]), (0,0,255), cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS) 
    (kps,features) = descriptor.detectAndCompute(image_with_keypoints,None)
    cv2.drawKeypoints(image_with_keypoints,kp,image)   
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    hist = cv2.calcHist([hsv], [0, 1, 2], None, (8, 8, 8),[0, 180, 0, 256, 0, 256])
    hist = cv2.normalize(hist,hist)
    hist=hist.flatten()
    test.append(hist)
    test_labels.append(2)
######################################################################################################

# %% [markdown]
# steps of the above cell:
# * iteration over the data of the four classes (botth train and test data for each)
# * for each image :
#     *  calculate its path
#     *  feature extraction usinf blob detector
#     *  feature discription using SIFT
#     *  get image histogram
#     *  add the histogram to the train/ test  data
#     *  add its label to the test /train lables

# %%
classifier=KNeighborsClassifier()
classifier.fit(train, train_labels)
acc = classifier.score(test,  test_labels)
print(acc)
# Out:
# 0.833333333333
